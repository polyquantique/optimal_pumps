# %%
import optimization_SPDC
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import jax.scipy.optimize as jax_opt

key = jax.random.PRNGKey(0)
np.random.seed(0)

# %% [markdown]
# # Initialize the parameters to build U matrix

# %%
# power of the pump (if too high, may affect the loss function(increasing loss))
Np = 0.2
# create the frequency matrix ω-ω_mean (maybe also influences the quality of the backprop)
N = 701
wi = -7
wf = 7
x = np.linspace(wi, wf, N)
# get the group velocities for all modes
vp = 0.1
sigma = 1
a = 1.61/1.13
l = 1
def symmetric_v(vp, sigma, l, a):
    vi = vp / (1 - 2 * a * vp / (l * sigma))
    vs = vp / (1 + 2 * a * vp / (l * sigma))
    return vs, vi
vs, vi = symmetric_v(vp, sigma, l, a)
# prefactor to multiply pump with to obtain F matrix
alpha = np.sqrt(Np)*(x[len(x) - 1] - x[0])/(len(x) - 1)/(np.sqrt(2 * np.pi * vs * vi * vp))
# initialize the G and H matrices without cross phase modulation
G = np.diag((1/vs - 1/vp)*x)
H = np.diag((1/vi - 1/vp)*x)

# %% [markdown]
# # Initialize the desired value for mean pair number (N) and Schmidt number (K)

# %%
y_N = 40
y_K = 1

# %% [markdown]
# # Initializing with a gaussian pump

# %%
def get_total_loss(a, size: int, alpha, G, H, l, y_N, y_K):
    loss_K = optimization_SPDC.get_euclidean_loss_K(a, size, alpha, G, H, l, y_K)
    loss_N = optimization_SPDC.get_euclidean_loss_N(a, size, alpha, G, H, l, y_N)
    return loss_K + loss_N

# %%
# If initialized with imaginary part not equal to real, optimized function phase can be weird 
# here the initial imaginary part is 5 times the initial real part
a = []
a.append(0.02*jnp.exp(-(jnp.linspace(2*wi, 2*wf, 2*N))**2))
a.append(0.1*jnp.exp(-(jnp.linspace(2*wi, 2*wf, 2*N))**2))
a = jnp.array(a)
a = jnp.reshape(a, 2*len(a[0]))
optimized = jax_opt.minimize(get_total_loss, a, args = (N, alpha, G, H, l, y_N, y_K), method = "BFGS")

# %%
optimized_a = optimized.x
complex_opt_a = optimization_SPDC.get_complex_array(optimized_a)
complex_a = optimization_SPDC.get_complex_array(a)

# %% [markdown]
# # Initializing with infinite bandwidthsech

# %%
a = 0.1*jnp.ones(4*N)
optimized = jax_opt.minimize(get_total_loss, a, args = (N, alpha, G, H, l, y_N, y_K), method = "BFGS")

# %%
optimized_a = optimized.x
complex_opt_a = optimization_SPDC.get_complex_array(optimized_a)
complex_a = optimization_SPDC.get_complex_array(a)

# %% [markdown]
# # Show the JSA power map

# %%
JSA = optimization_SPDC.get_JSA(x, optimized_a, N, alpha, G, H, l)
fig, ax = plt.subplots()
im = ax.imshow(JSA, cmap="jet", origin="lower",extent=[x[0],x[N-1],x[0],x[N-1]])
ax.set_title("JSA")
ax.set_xlabel(r"$(\omega_{s}-\bar{\omega}_{s})/\sigma$")
ax.set_ylabel(r"$(\omega_{i}-\bar{\omega}_{i})/\sigma$")
plt.colorbar(im, orientation="vertical")
plt.show()

# %% [markdown]
# # Show the pump envelopp

# %%
plt.title("Absolute value of pump envelop normalized by absolute norm")
plt.xlabel("ω_s + ω_i")
plt.ylabel("Amplitude of pump envelop")
plt.plot(jnp.abs(complex_a/sum(jnp.abs(complex_a))), label = "before optimization")
plt.plot(jnp.abs(complex_opt_a/sum(jnp.abs(complex_opt_a))), label = "after optimization")
plt.legend()

# %%
plt.title("Phase of pump envelop normalized by absolute norm")
plt.xlabel("ω_s + ω_i")
plt.ylabel("Amplitude of pump envelop")
plt.plot(jnp.angle(complex_a/sum(jnp.abs(complex_a))), label = "before optimization")
plt.plot(jnp.angle(complex_opt_a/sum(jnp.abs(complex_opt_a))), label = "after optimization")
plt.legend()

# %%
plt.plot(jnp.angle(complex_opt_a/sum(jnp.abs(complex_opt_a))), label = "after optimization")

# %%
plt.title("Norm of pump envelop normalized by absolute norm")
plt.xlabel("ω_s + ω_i")
plt.ylabel("Amplitude of pump envelop")
plt.plot((optimized.x), label = "after optimization")
plt.legend()

# %%
optimization_SPDC.get_observables(optimized_a, N, alpha, G, H, l)
# Out:
# (DeviceArray(39.73918, dtype=float32), DeviceArray(1.0806807, dtype=float32))
