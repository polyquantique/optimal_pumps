# %%
import optimization_SPDC
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import jax.scipy.optimize as jax_opt
import get_initialization_cond as init_value

key = jax.random.PRNGKey(0)
np.random.seed(0)
#perhaps add a callback for progress bar?

# %% [markdown]
# # Initialize the parameters to build U matrix

# %%
# power of the pump (if too high, may affect the loss function(increasing loss))
# Evolution of dL/dbeta_i depends heavily on values of beta_j
Np = 0.001
# create the frequency matrix ω-ω_mean (maybe also influences the quality of the backprop)
N = 601
wi = -10
wf = 10
x = np.linspace(wi, wf, N)
l = 1
vp = 0.1
alpha, G, H = init_value.get_constants(vp, l, wi, wf, Np, N)

# %% [markdown]
# # Initialize the desired value for mean pair number (N) and Schmidt number (K)

# %%
y_N = 1
y_K = 1

# %% [markdown]
# # Initializing with a gaussian pump

# %%
# Possibly the algorithm doesnt make beta values vary until where an acceptable solution is satisfied
# or change the form of the penalty function. A form that is 0 if inside domain of interest and inf outside
# One should learly define the penalty condition as f(x)<0 or make a multi objective optimization problem
def penalize_border_effects(a,wi,wf):
    # Not the right loss...
    omega = jnp.linspace(2*wi, 2*wf, 2*N)
    real = a[:len(a)//2]
    imag = a[len(a)//2:]
    norm = jnp.sqrt(real**2+imag**2)
    return jnp.sum((omega*norm)**2)
def total_loss(a, size: int, alpha, G, H, l, y_N, y_K, wi, wf):
    loss = optimization_SPDC.get_total_loss(a, size, alpha, G, H, l, y_N, y_K)
    border_penalty = penalize_border_effects(a, wi, wf)
    return border_penalty#+ 0.8*loss

# %%
method = "hermite"
init_params = [0, 0.1, 2, np.pi/3]
a = init_value.get_initialization_array(init_params, vp, l, wi, wf, Np, method = method, N = N)
optimized = jax_opt.minimize(optimization_SPDC.get_total_loss,a , args=(N, alpha, G, H, l, y_N, y_K), method = "BFGS")
optimized_a = optimized.x
complex_opt_a = optimization_SPDC.get_complex_array(optimized_a)
complex_a = optimization_SPDC.get_complex_array(a)

# %% [markdown]
# # Initializing with infinite bandwidth

# %%
a = 0.1*jnp.ones(4*N)
optimized = jax_opt.minimize(optimization_SPDC.get_total_loss, a, args = (N, alpha, G, H, l, y_N, y_K), method = "BFGS", options=dict(maxiter = 10e6, gtol = 10e-6))

# %%
optimized_a = optimized.x
complex_opt_a = optimization_SPDC.get_complex_array(optimized_a)
complex_a = optimization_SPDC.get_complex_array(a)

# %% [markdown]
# # Show the JSA power map

# %%
JSA = optimization_SPDC.get_JSA(x, optimized_a, N, alpha, G, H, l)
fig, ax = plt.subplots()
im = ax.imshow(JSA, cmap="jet", origin="lower",extent=[x[0],x[N-1],x[0],x[N-1]])
ax.set_title("JSA for number of pairs equal to 10")
ax.set_xlabel(r"$(\omega_{s}-\bar{\omega}_{s})/\sigma$")
ax.set_ylabel(r"$(\omega_{i}-\bar{\omega}_{i})/\sigma$")
plt.colorbar(im, orientation="vertical")
plt.savefig("optimized_pump_10_N.pdf")
plt.show()

# %%
# save the data as dict
data = {
    "Np":Np,
    "N":N,
    "initial guess": a,
    "optimized pump": optimized_a
}
np.save("constant_init", data)

# %% [markdown]
# # Analysis of gradients with the borders penalty

# %%
# Gradient without the "penalty"
# Wtf first run is different from the 2nd run
print("norm of gradient with penalty: ", sum(jnp.abs(jax.grad(total_loss)(optimized_a, N, alpha, G, H, l, y_N, y_K, wi, wf))))
print("norm of gradient of loss term: ", sum(jnp.abs(jax.grad(optimization_SPDC.get_total_loss)(optimized_a, N, alpha, G, H, l, y_N, y_K))))
print("norm of gradient of penalty term: ", sum(jnp.abs(jax.grad(penalize_border_effects,argnums=(2))(wi,wf,optimized_a))))
print("N and K values: ", optimization_SPDC.get_observables(optimized_a, N, alpha, G, H, l))
# Out:
# N and K values:  (DeviceArray(1.006644, dtype=float32), DeviceArray(1.142742, dtype=float32))

# %%
# Gradient with the "penalty" for comparison
print("norm of gradient with penalty: ", sum(jnp.abs(jax.grad(total_loss)(optimized_a, N, alpha, G, H, l, y_N, y_K, wi, wf))))
print("norm of gradient of loss term: ", sum(jnp.abs(jax.grad(optimization_SPDC.get_total_loss)(optimized_a, N, alpha, G, H, l, y_N, y_K))))
print("norm of gradient of penalty term: ", sum(jnp.abs(jax.grad(penalize_border_effects,argnums=(2))(wi,wf,optimized_a))))
print("N and K values: ", optimization_SPDC.get_observables(optimized_a, N, alpha, G, H, l))
# Out:
# norm of gradient with penalty:  214.15275145268424
# norm of gradient of loss term:  263.2275046701834
# norm of gradient of penalty term:  50.35444919743111
# N and K values:  (DeviceArray(1.363153e-05, dtype=float32), DeviceArray(1.2905581, dtype=float32))

# %% [markdown]
# # Show the pump envelopp

# %%
plt.title("Absolute value of pump envelop normalized by absolute norm")
plt.xlabel("ω_s + ω_i")
plt.ylabel("Amplitude of pump envelop")
plt.plot(jnp.abs(complex_a/(jnp.linalg.norm(complex_a))), label = "before optimization")
plt.plot(jnp.abs(complex_opt_a/(jnp.linalg.norm(complex_opt_a))), label = "after optimization")
plt.legend()

# %%
plt.title("Phase of pump envelop normalized by absolute norm")
plt.xlabel("ω_s + ω_i")
plt.ylabel("Amplitude of pump envelop")
plt.plot(jnp.angle(complex_a/(jnp.linalg.norm(complex_a))), label = "before optimization")
plt.plot(jnp.angle(complex_opt_a/(jnp.linalg.norm(complex_opt_a))), label = "after optimization")
plt.legend()

# %%
optimization_SPDC.get_observables(optimized_a, N, alpha, G, H, l)
# Out:
# (DeviceArray(1.0066242, dtype=float32), DeviceArray(1.1429238, dtype=float32))
